# %%
#importing all the required libraries
from keras.models import Sequential
from keras.layers import Dense, Activation, Conv2D, MaxPooling2D, Flatten, Dropout
from keras.datasets import mnist
from keras.optimizers import SGD, Adam
import tensorflow as tf

# %%
#loading the mnist dataset and splitting it into training and test dataset
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

X_train = X_train.reshape((-1, 28, 28, 1)).astype('float32')/255
X_test = X_test.reshape((-1, 28, 28, 1)).astype('float32')/255

Y_train=tf.one_hot(Y_train, 10)
Y_test=tf.one_hot(Y_test, 10)
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
#defining the model
model = Sequential([
    Conv2D(128, (3,3), activation = 'relu', input_shape = (28, 28, 1)),
    MaxPooling2D((2,2)),

    Conv2D(64, (5,5), activation = 'relu'),
    #MaxPooling2D((2,2)),

    Conv2D(32, (7,7), activation = 'relu'),
    MaxPooling2D((2,2)),

    Flatten(),
    Dense(128, activation = 'relu'),
    Dropout(0.5),
    Dense(10, activation = 'softmax')
])

model.compile(optimizer = Adam (learning_rate = 0.00075), loss = 'mean_squared_error', metrics = ['accuracy'])
model.fit(X_train, Y_train, epochs = 10, batch_size = 32, validation_data = (X_test,Y_test))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 297s 158ms/step - loss: 0.0097 - accuracy: 0.9330 - val_loss: 0.0026 - val_accuracy: 0.9824
# Epoch 2/10
# 1875/1875 [==============================] - 287s 153ms/step - loss: 0.0030 - accuracy: 0.9814 - val_loss: 0.0023 - val_accuracy: 0.9852
# Epoch 3/10
# 1875/1875 [==============================] - 277s 148ms/step - loss: 0.0021 - accuracy: 0.9867 - val_loss: 0.0017 - val_accuracy: 0.9892
# Epoch 4/10
# 1875/1875 [==============================] - 262s 140ms/step - loss: 0.0017 - accuracy: 0.9894 - val_loss: 0.0015 - val_accuracy: 0.9906
# Epoch 5/10
# 1875/1875 [==============================] - 264s 141ms/step - loss: 0.0015 - accuracy: 0.9906 - val_loss: 0.0014 - val_accuracy: 0.9916
# Epoch 6/10
# 1875/1875 [==============================] - 263s 140ms/step - loss: 0.0014 - accuracy: 0.9917 - val_loss: 0.0013 - val_accuracy: 0.9918
# Epoch 7/10
# ...
